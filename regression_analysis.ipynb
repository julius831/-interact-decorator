# %% [markdown]
# <a href="https://colab.research.google.com/github/julius831/-interact-decorator/blob/main/regression_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Project: Predicting Fuel Efficiency (MPG) to Reduce Carbon Footprint and Enable Data-Driven Policy**
#
# Governments worldwide are under increasing pressure to reduce greenhouse gas emissions from the transportation sector, one of the largest contributors to environmental pollution. Fuel consumption in vehicles is directly linked to carbon emissions, making fuel efficiency—measured in miles per gallon (MPG)—a critical metric for environmental policy, economic planning, and sustainable development.
#
# As a **data scientist working for a government agency**, your task is to develop a predictive model that estimates a vehicle’s MPG based on its technical and design characteristics, such as engine size, horsepower, weight, number of cylinders, and origin. By accurately predicting fuel efficiency, the government can better understand which vehicle attributes contribute most to fuel consumption and emissions.
#
# Beyond environmental benefits, this model will also support:
#
# * **Cost optimization for citizens and public fleets** by identifying fuel-efficient vehicle options
# * **Improved transportation planning** through better forecasting of fuel demand
# * **Informed taxation and subsidy policies**, such as incentives for fuel-efficient or electric vehicles
# * **Support for automotive innovation** by highlighting design factors that improve efficiency
# * **Enhanced consumer awareness**, enabling data-driven vehicle choices
# * **National energy conservation strategies**, reducing dependence on fuel imports
#
# The insights from this model will enable:
#
# * The design of **evidence-based fuel efficiency regulations**
# * Identification of **high-emission vehicle profiles**
# * Development of **targeted incentive programs for low-emission vehicles**
# * Strategic interventions to **reduce the national carbon footprint**

# %% [markdown]
# **import libraries**

# %% [markdown]
# import libraries
# import data
# EDA
# modelling
#
# 1.  preprocessing
# 2.  instantiate the models
# evaluate the data
#
#
#
#
#
#
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score

# %% [markdown]
# **load the data**

# %%
df = sns.load_dataset("mpg")

# %% [markdown]
# **show the data**

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# **exploratory data analysis**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.describe(include= "all")
# Out:
#                mpg   cylinders  displacement  horsepower       weight  \
# count   398.000000  398.000000    398.000000  392.000000   398.000000
# unique         NaN         NaN           NaN         NaN          NaN
# top            NaN         NaN           NaN         NaN          NaN
# freq           NaN         NaN           NaN         NaN          NaN
# mean     23.514573    5.454774    193.425879  104.469388  2970.424623
# std       7.815984    1.701004    104.269838   38.491160   846.841774
# min       9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%      17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%      23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%      29.000000    8.000000    262.000000  126.000000  3608.000000
# max      46.600000    8.000000    455.000000  230.000000  5140.000000
#
#         acceleration  model_year origin        name
# count     398.000000  398.000000    398         398
# ...

# %% [markdown]
# min mpg is 9 which car?
# max mpg is 46 which car ?

# %%
df[df["mpg"]== df['mpg'].min()]['name']
# Out:
# 28    hi 1200d
# Name: name, dtype: object

# %%
df[df["mpg"]== df['mpg'].max()]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0        65.0    2110          17.9
#
#      model_year origin       name
# 322          80  japan  mazda glc

# %%
df[df["weight"]== df['weight'].max()]
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 44  13.0          8         400.0       175.0    5140          12.0
#
#     model_year origin                 name
# 44          71    usa  pontiac safari (sw)

# %% [markdown]
# drop the the mpg on our  first row and name
#
#
# ```
# # This is formatted as code
# ```

# %%
y = df["mpg"]
X = df.drop(["mpg","name"] ,axis=1)

# %%
pd.get_dummies(X,drop_first=True)
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0    3504          12.0          70
# 1            8         350.0       165.0    3693          11.5          70
# 2            8         318.0       150.0    3436          11.0          70
# 3            8         304.0       150.0    3433          12.0          70
# 4            8         302.0       140.0    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0    2790          15.6          82
# 394          4          97.0        52.0    2130          24.6          82
# 395          4         135.0        84.0    2295          11.6          82
# 396          4         120.0        79.0    2625          18.6          82
# 397          4         119.0        82.0    2720          19.4          82
#
#      origin_japan  origin_usa
# 0           False        True
# ...

# %% [markdown]
# **ensure one variable is not influencing another with standard scaler**

# %%
X['horsepower'] = X['horsepower'].fillna(X['horsepower'].mean())
X = pd.get_dummies(X,drop_first=True)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=60)

# %% [markdown]
# **fit**

# %%
rf = RandomForestRegressor(random_state=33)
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=33)

# %%
y_pred = rf.predict(X_test)

# %% [markdown]
# evaluate our model

# %%
root_mean_squared_error = np.sqrt(mean_squared_error(y_test,y_pred))
print(root_mean_squared_error)
# Out:
# 2.614276649476867

# %%
r2_score = r2_score(y_test,y_pred)
print(r2_score)
# Out:
# 0.8608215584834359

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Using `SimpleImputer` in a Pipeline

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Identify numerical and categorical features
# Note: 'name' and 'mpg' (target) are already dropped from X

numerical_features = ['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model_year']
categorical_features = ['origin']

# Create preprocessing pipelines for numerical and categorical features
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Create a preprocessor using ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Create the full pipeline with a RandomForestRegressor
pipeline_rf = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(random_state=33))
])

# Split data using the original X and y (before any manual scaling or get_dummies)
X_train_pipe, X_test_pipe, y_train_pipe, y_test_pipe = train_test_split(X, y, test_size=0.2, random_state=60)

# Fit the pipeline
pipeline_rf.fit(X_train_pipe, y_train_pipe)

# %%
# Make predictions
y_pred_pipe = pipeline_rf.predict(X_test_pipe)

# Evaluate the pipeline model
rmse_pipe = np.sqrt(mean_squared_error(y_test_pipe, y_pred_pipe))
r2_pipe = r2_score(y_test_pipe, y_pred_pipe)

print(f"Pipeline Model RMSE: {rmse_pipe}")
print(f"Pipeline Model R2 Score: {r2_pipe}")
